# %% [markdown]
# <a href="https://colab.research.google.com/github/felippedamasopy/Web-Scraping/blob/main/Simple_Web_Scraping.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd

url='https://www.federalreserve.gov/releases/h3/current/default.htm'
response = requests.get(url)
html = response.content
soup = BeautifulSoup(html, 'html.parser')
table = soup.findAll('table')
html_file = f'<html><body>{table}</body></html>'
html = pd.read_html(html_file)

# %%
# there are 3 lists you acess the lists in this format html[0], html[1], html[3]
html
# Out:
# [                  Date      Reserve balances required  \
#                    Date Reserve balance requirements 1
#  0              Month 7                        Month 7
#  1            Aug. 2019                         134639
#  2           Sept. 2019                         134707
#  3            Oct. 2019                         134998
#  4            Nov. 2019                         140705
#  5            Dec. 2019                         138984
#  6            Jan. 2020                         144816
#  7            Feb. 2020                         138370
#  8            Mar. 2020                         113139
#  9            Apr. 2020                              0
#  10            May 2020                              0
#  11           June 2020                              0
#  12           July 2020                              0
#  13           Aug. 2020                              0
#  14                 NaN                            NaN
# ...

# %%
html[0].head(1)
# Out:
#       Date      Reserve balances required                              \
#       Date Reserve balance requirements 1 Top of penalty- free band 2
# 0  Month 7                        Month 7                     Month 7
#
#                                  Reserve balances maintained 4  \
#   Bottom of penalty- free band 3                         Total
# 0                        Month 7                       Month 7
#
#                                                                  \
#   Balances maintained to satisfy reserve balance requirements 5
# 0                                            Month 7
#
#
#   Balances maintained that exceed the top of the penalty- free band 6
# 0                                            Month 7

# %%
html[1].head(1)
# Out:
#       Date Reserves          Vault cash 2                                      \
#       Date  Total 1 Required        Total Used to satisfy required reserves 3
# 0  Month 7  Month 7  Month 7      Month 7                             Month 7
#
#             Monetary base
#   Surplus 4       Total 5 Total balances maintained 6 Currency in circulation
# 0   Month 7       Month 7                     Month 7                 Month 7

# %%
html[2].head(1)
# Out:
#       Date Borrowings from the Federal Reserve                              \
#       Date                               Total  Primary Secondary Seasonal
# 0  Month 3                             Month 3  Month 3   Month 3  Month 3
#
#                             Nonborrowed reserves 2
#   Other credit extensions 1 Nonborrowed reserves 2
# 0                   Month 3                Month 3
